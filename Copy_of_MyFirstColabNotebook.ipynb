# %% [markdown]
# <a href="https://colab.research.google.com/github/MullacMc/demo/blob/main/Copy_of_MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Thu Sep 17 14:14:24 2026

# %% [markdown]
# This is **bold**
# This is *italic*
# This is ~strikethrough~

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %% [markdown]
# $e^x = \sum_{i = 0}^\infty \frac{1}{i!}x^i$

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Thu Sep 17 14:14:29 2026
